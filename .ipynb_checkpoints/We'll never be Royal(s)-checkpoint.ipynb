# %% [markdown]
# # More Accurate Data Pre-Processing

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')

# %% [markdown]
# ### Much easier way to obtain and manipulate the CSV file with Pandas

# %%
df.head()
# Out:
#               date  TotalConsmp     R1        H_1    R2        H_2     R3  \
# 0  1/11/2016 17:00           90  19.89  47.596667  19.2  44.790000  19.79
# 1  1/11/2016 17:10           90  19.89  46.693333  19.2  44.722500  19.79
# 2  1/11/2016 17:20           80  19.89  46.300000  19.2  44.626667  19.79
# 3  1/11/2016 17:30           90  19.89  46.066667  19.2  44.590000  19.79
# 4  1/11/2016 17:40          100  19.89  46.333333  19.2  44.530000  19.79
#
#          H_3         R4        H_4     ...            H_7    R8        H_8  \
# 0  44.730000  19.000000  45.566667     ...      41.626667  18.2  48.900000
# 1  44.790000  19.000000  45.992500     ...      41.560000  18.2  48.863333
# 2  44.933333  18.926667  45.890000     ...      41.433333  18.2  48.730000
# 3  45.000000  18.890000  45.723333     ...      41.290000  18.1  48.590000
# 4  45.000000  18.890000  45.530000     ...      41.230000  18.1  48.590000
#
# ...

# %% [markdown]
# ### Scatter Matrix lets us check all correlations instantaneously. Much more affective than going one-by-one

# %%
# checking correlations 
from pandas.plotting import scatter_matrix
subset = df[['TotalConsmp','TempOutSide','Press_mm_hg','H_OutSide','Windspeed','Visibility']]
scatter_matrix(subset,figsize=(10,10)) #(subset, alpha=0.2, figsize=(6, 6), diagonal='kde')
plt.show()

# %%
import seaborn as sns

# %% [markdown]
# ### Data Visualization w/ Seaborn makes it much easier (and effective) to check correlations

# %%
cols = ['TotalConsmp','TempOutSide','Press_mm_hg','H_OutSide','Windspeed','Visibility']
cm = np.corrcoef(subset.values.T)
sns.set(font_scale=1.5)
plt.figure(figsize=(10,10))
hm = sns.heatmap(cm,
                 cbar=True,
                 annot=True,
                 square=True,
                 fmt='.2f',
                 annot_kws= {'size': 10},
                 yticklabels = cols,
                 xticklabels=cols
                )
plt.show()

# %% [markdown]
# ## Even with more accurate data-processing, no correlations seem to exist between the different types of data and energy consumption
